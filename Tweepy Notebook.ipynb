# %%
import tweepy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tweepy

# Authenticate to Twitter
auth = tweepy.OAuthHandler("CONSUMER_KEY", "CONSUMER_SECRET")
auth.set_access_token("ACCESS_TOKEN", "ACCESS_TOKEN_SECRET")



# Create API object
#api = tweepy.API(auth)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
# Create a tweet
#api.update_status("Hello Tweepy")

#public_tweets = api.search('homeless')
results = api.search('homeless')
#for tweet in public_tweets:
#    print(tweet.text)

#Consumer API keys

#bSCSPnXD1W8vtp73N2j9kP5aO (API key)

#5VMLDPJkLUIsUCkBULRvbfB1rihGxKNus62CZzexRm04DS1juo (API secret key)

#Access token & access token secret

#2257754240-nmosIVlMPNuMFUTBp7bdXPO9P4hPPchTSuXNH03 (Access token)

#VqerC7XGivanazVVROXmXepPluu0jHzoWNnvHMYkkb0lT (Access token secret)

# %%
results.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
results['search_metadata']
# Out:
# {'completed_in': 0.074,
#  'count': 15,
#  'max_id': 1179540592222773248,
#  'max_id_str': '1179540592222773248',
#  'next_results': '?max_id=1179540576561008639&q=homeless&include_entities=1',
#  'query': 'homeless',
#  'refresh_url': '?since_id=1179540592222773248&q=homeless&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
results['statuses']
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Oct 02 23:36:06 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 224749835,
#      'id_str': '224749835',
#      'indices': [3, 15],
#      'name': 'liane gomersall',
#      'screen_name': 'ligomersall'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1179540592222773248,
#   'id_str': '1179540592222773248',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 123,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Oct 02 18:32:02 +0000 2019',
# ...

# %%
pd.DataFrame(results['statuses'])['entities'][0]['user_mentions']
# Out:
# [{'id': 224749835,
#   'id_str': '224749835',
#   'indices': [3, 15],
#   'name': 'liane gomersall',
#   'screen_name': 'ligomersall'}]

# %%
#override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
#http://docs.tweepy.org/en/latest/streaming_how_to.html
myStream.filter(track=['homeless'])
# Out:
# RT @BienSur_JeTaime: A reminder that the vast majority of us are one medical emergency away from ending up on the same streets we vilify th…
# RT @BienSur_JeTaime: A reminder that the vast majority of us are one medical emergency away from ending up on the same streets we vilify th…
# RT @lloyd4man: Tomi Lahren: CA Democrats ignoring homeless 'epidemic' in favor of Trump impeachment push
#
# https://t.co/l7JmIICNNg
# RT @BienSur_JeTaime: A reminder that the vast majority of us are one medical emergency away from ending up on the same streets we vilify th…
# RT @GregAbbott_TX: Today I sent a letter to @MayorAdler about the growing crisis arising from the Austin Homeless policy.
#
# Feces &amp; used nee…
# RT @BienSur_JeTaime: A reminder that the vast majority of us are one medical emergency away from ending up on the same streets we vilify th…
# RT @Atlantide4world: Mysterious viral LA subway singer is revealed as classically trained musician who was made homeless by medical bills a…
# ...

# %%
# Out:
#    contributors coordinates                      created_at  \
# 0          None        None  Wed Oct 02 23:36:06 +0000 2019
# 1          None        None  Wed Oct 02 23:36:06 +0000 2019
# 2          None        None  Wed Oct 02 23:36:06 +0000 2019
# 3          None        None  Wed Oct 02 23:36:06 +0000 2019
# 4          None        None  Wed Oct 02 23:36:06 +0000 2019
# 5          None        None  Wed Oct 02 23:36:06 +0000 2019
# 6          None        None  Wed Oct 02 23:36:05 +0000 2019
# 7          None        None  Wed Oct 02 23:36:04 +0000 2019
# 8          None        None  Wed Oct 02 23:36:04 +0000 2019
# 9          None        None  Wed Oct 02 23:36:03 +0000 2019
# 10         None        None  Wed Oct 02 23:36:03 +0000 2019
# 11         None        None  Wed Oct 02 23:36:03 +0000 2019
# 12         None        None  Wed Oct 02 23:36:03 +0000 2019
# 13         None        None  Wed Oct 02 23:36:02 +0000 2019
# 14         None        None  Wed Oct 02 23:36:02 +0000 2019
#
# ...
